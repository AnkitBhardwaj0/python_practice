# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go
import plotly.offline as pyo

# %%
matches=pd.read_csv('matches.csv')
delivery=pd.read_csv('deliveries.csv')
ipl=delivery.merge(matches,left_on='match_id',right_on='id')
ipl.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  result  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...  normal
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...  normal
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...  normal
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...  normal
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...  normal
#
#    dl_applied               winner  win_by_runs  win_by_wickets  \
# ...

# %%
#scatter plots
#problem :- we are going to draw a scatter plot between batsman avg (x-axis) and 
# batsman strike rate on y asix of top 50 batsman in ipl all time

# %%
#avg vs sr graph of top 50 batsman (in term of total runs)

top50=ipl.groupby('batsman')['batsman_runs'].sum().sort_values(ascending=False).head(50).index.tolist()
new_ipl=ipl[ipl['batsman'].isin(top50)]

# %%
#calculating sr
runs=new_ipl.groupby('batsman')['batsman_runs'].sum()
balls=new_ipl.groupby('batsman')['batsman_runs'].count()
sr=(runs/balls)*100
sr=sr.reset_index()
sr
# Out:
#              batsman  batsman_runs
# 0     AB de Villiers    145.129059
# 1       AC Gilchrist    133.054662
# 2           AJ Finch    126.299213
# 3          AM Rahane    117.486549
# 4          AT Rayudu    123.014257
# 5        BB McCullum    126.318203
# 6           BJ Hodge    121.422376
# 7           CH Gayle    144.194313
# 8          DA Miller    137.709251
# 9          DA Warner    138.318401
# 10          DJ Bravo    122.286822
# 11         DJ Hussey    120.072661
# 12  DPMD Jayawardene    118.791064
# 13          DR Smith    132.279534
# 14      F du Plessis    124.161074
# 15         G Gambhir    120.361200
# 16        GJ Maxwell    157.564103
# 17         JH Kallis    105.936272
# 18         JP Duminy    121.970624
# 19        KA Pollard    140.621266
# 20     KC Sangakkara    118.469101
# 21        KD Karthik    123.008475
# 22           KK Nair    124.650161
# 23           M Vijay    120.028681
# 24        MEK Hussey    119.963592
# 25         MK Pandey    116.938453
# ...

# %%
#calculating avg
#avg=(total number of runs)/(number of outs)
out=ipl[ipl['player_dismissed'].isin (top50)]
nout=out['player_dismissed'].value_counts()
avg=runs/nout
avg=avg.reset_index()
avg
# Out:
#              batsman          0
# 0     AB de Villiers  38.307692
# 1       AC Gilchrist  27.223684
# 2           AJ Finch  27.186441
# 3          AM Rahane  33.593407
# 4          AT Rayudu  27.146067
# 5        BB McCullum  28.112245
# 6           BJ Hodge  33.333333
# 7           CH Gayle  41.022472
# 8          DA Miller  34.733333
# 9          DA Warner  40.140000
# 10          DJ Bravo  22.945455
# 11         DJ Hussey  26.979592
# 12  DPMD Jayawardene  28.250000
# 13          DR Smith  28.392857
# 14      F du Plessis  30.116279
# 15         G Gambhir  31.541985
# 16        GJ Maxwell  25.081633
# 17         JH Kallis  28.552941
# 18         JP Duminy  39.860000
# 19        KA Pollard  28.707317
# 20     KC Sangakkara  25.953846
# 21        KD Karthik  24.811966
# 22           KK Nair  25.173913
# 23           M Vijay  26.431579
# 24        MEK Hussey  38.764706
# 25         MK Pandey  28.500000
# 26         MK Tiwary  29.428571
# 27          MS Dhoni  37.872340
# ...

# %%
df=avg.merge(sr,on='batsman')
df.rename(columns={0:'avg','batsman_runs':'sr'},inplace=True)
df
# Out:
#              batsman        avg          sr
# 0     AB de Villiers  38.307692  145.129059
# 1       AC Gilchrist  27.223684  133.054662
# 2           AJ Finch  27.186441  126.299213
# 3          AM Rahane  33.593407  117.486549
# 4          AT Rayudu  27.146067  123.014257
# 5        BB McCullum  28.112245  126.318203
# 6           BJ Hodge  33.333333  121.422376
# 7           CH Gayle  41.022472  144.194313
# 8          DA Miller  34.733333  137.709251
# 9          DA Warner  40.140000  138.318401
# 10          DJ Bravo  22.945455  122.286822
# 11         DJ Hussey  26.979592  120.072661
# 12  DPMD Jayawardene  28.250000  118.791064
# 13          DR Smith  28.392857  132.279534
# 14      F du Plessis  30.116279  124.161074
# 15         G Gambhir  31.541985  120.361200
# 16        GJ Maxwell  25.081633  157.564103
# 17         JH Kallis  28.552941  105.936272
# 18         JP Duminy  39.860000  121.970624
# 19        KA Pollard  28.707317  140.621266
# ...

# %%
#scatter plot

trace=go.Scatter(x=df['avg'],y=df['sr'],mode='markers',hovertext=df['batsman'],marker={'color':'#00a65a'})
data=[trace]
layout=go.Layout(title='batsman Avg vs sr',xaxis={'title':'Avg'},yaxis={'title':'sr'})
fig=go.Figure(data=data,layout=layout)
#pyo.plot(fig) #show in server
fig.show()

# %%
trace=go.Scatter(x=df['avg'],y=df['sr'],mode='markers',hovertext=df['batsman'],marker={'color':'#00a65a','size':16})
data=[trace]
layout=go.Layout(title='batsman Avg vs sr',xaxis={'title':'Avg'},yaxis={'title':'sr'})
fig=go.Figure(data=data,layout=layout)
fig.show()

# %%
trace=go.Scatter(x=df['avg'],y=df['sr'],mode='markers',hovertext=df['batsman'],marker={'color':'#00a65a','size':15})
data=[trace]
layout=go.Layout(title='batsman Avg vs sr',xaxis={'title':'Avg'},yaxis={'title':'sr'})
fig=go.Figure(data=data,layout=layout)
pyo.plot(fig,filename='myfile.html')
# Out:
# 'myfile.html'

# %% [markdown]
# ### Line chart

# %%
ipl.sample()
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 110856       468       1  Kolkata Knight Riders  Royal Challengers Bangalore
#
#         over  ball  batsman non_striker          bowler  is_super_over  ...  \
# 110856     9     1  CA Lynn   JH Kallis  M Muralitharan              0  ...
#
#         result  dl_applied                 winner  win_by_runs  \
# 110856  normal           0  Kolkata Knight Riders            2
#
#         win_by_wickets  player_of_match                    venue    umpire1  \
# 110856               0          CA Lynn  Sharjah Cricket Stadium  Aleem Dar
#
#             umpire2 umpire3
# 110856  VA Kulkarni     NaN
#
# [1 rows x 39 columns]

# %%
# year by year performance batsman 
single=ipl[ipl['batsman']=='V Kohli']
performance=single.groupby('season')['batsman_runs'].sum().reset_index()
performance
# Out:
#    season  batsman_runs
# 0    2008           165
# 1    2009           246
# 2    2010           307
# 3    2011           557
# 4    2012           364
# 5    2013           639
# 6    2014           359
# 7    2015           505
# 8    2016           973
# 9    2017           308

# %%
trace=go.Scatter(x=performance['season'],y=performance['batsman_runs'],mode='lines',marker={'color':'#00a65a'})
data=[trace]
layout=go.Layout(title='year by year performance',xaxis={'title':'season'},yaxis={'title':'performance'})
fig=go.Figure(data=data,layout=layout)
fig.show()

# %%
trace=go.Scatter(x=performance['season'],y=performance['batsman_runs'],mode='lines+markers',marker={'color':'#00a65a'})
data=[trace]
layout=go.Layout(title='year by year performance',xaxis={'title':'season'},yaxis={'title':'performance'})
fig=go.Figure(data=data,layout=layout)
fig.show()

# %%
single1=ipl[ipl['batsman']=='MS Dhoni']
performance1=single1.groupby('season')['batsman_runs'].sum().reset_index()
performance1
# Out:
#    season  batsman_runs
# 0    2008           414
# 1    2009           332
# 2    2010           287
# 3    2011           392
# 4    2012           357
# 5    2013           461
# 6    2014           371
# 7    2015           372
# 8    2016           284
# 9    2017           290

# %%
trace=go.Scatter(x=performance['season'],y=performance['batsman_runs'],mode='lines+markers',marker={'color':'#00a65a'},name='Virat Kohli')

trace1=go.Scatter(x=performance1['season'],y=performance1['batsman_runs'],mode='lines+markers',marker={'color':"#0011a6"},name='MS Dhoni')

data=[trace,trace1]
layout=go.Layout(title='year by year performance',xaxis={'title':'season'},yaxis={'title':'performance'})
fig=go.Figure(data=data,layout=layout)
fig.show()

# %%
#multiple line charts
def batsman_comp(*name):
     data=[]
     for i in name:
          single=ipl[ipl['batsman']==i]
          performance=single.groupby('season')['batsman_runs'].sum().reset_index()
          trace=go.Scatter(x=performance['season'],y=performance['batsman_runs'],mode='lines+markers',name=i)
          data.append(trace)
          layout=go.Layout(title='year by year performance',xaxis={'title':'season'},yaxis={'title':'runs'})
          fig=go.Figure(data=data,layout=layout)
          fig.show()

# %%
batsman_comp('V Kohli','RG Sharma','DA Warner','MS Dhoni')

# %%
#multiple line charts
def batsman_comp1(*name):
     data=[]
     for i in name:
          single=ipl[ipl['batsman']==i]
          performance=single.groupby('season')['batsman_runs'].sum().reset_index()
          trace=go.Scatter(x=performance['season'],y=performance['batsman_runs'],mode='lines+markers',name=i)
          data.append(trace)
          layout=go.Layout(title='year by year performance',xaxis={'title':'season'},yaxis={'title':'runs'})
          fig=go.Figure(data=data,layout=layout)
          pyo.plot(fig)

# %%
batsman_comp1('V Kohli','RG Sharma','DA Warner','MS Dhoni')

# %% [markdown]
# ### Bar plot

# %%
top10=ipl.groupby('batsman')['batsman_runs'].sum().sort_values(ascending=False).head(10).index.tolist()
top10_df=ipl[ipl['batsman'].isin(top10)]

# %%
top10_score=top10_df.groupby('batsman')['batsman_runs'].sum().reset_index()
top10_score
# Out:
#           batsman  batsman_runs
# 0  AB de Villiers          3486
# 1        CH Gayle          3651
# 2       DA Warner          4014
# 3       G Gambhir          4132
# 4        MS Dhoni          3560
# 5       RG Sharma          4207
# 6      RV Uthappa          3778
# 7        S Dhawan          3561
# 8        SK Raina          4548
# 9         V Kohli          4423

# %%
#plot bar graph
trace=go.Bar(x=top10_score['batsman'],y=top10_score['batsman_runs'],marker={'color':'orange'})
data=[trace]
layout=go.Layout(title='top 10 ipl batsman',xaxis={'title':'batsman'},yaxis={'title':'batsman_run'})
fig=go.Figure(data=data,layout=layout)
fig.show()

# %% [markdown]
# > there are 2 types of Bar Graph
# 1. nested Bar graph
# 2. stacked Bar graph
# 3. overlayed Bar graph

# %%
iw=top10_df.groupby(['batsman','inning'])['batsman_runs'].sum().reset_index()
mask=iw['inning']==1
mask2=iw['inning']==2
one=iw[mask]
two=iw[mask2]

one.rename(columns={'batsman_runs':'1st innings'},inplace=True)
two.rename(columns={'batsman_runs':'2nd innings'},inplace=True)
final=one.merge(two,on='batsman')[['batsman','1st innings','2nd innings']]
final
# Out:
#           batsman  1st innings  2nd innings
# 0  AB de Villiers         2128         1345
# 1        CH Gayle         2003         1623
# 2       DA Warner         2118         1896
# 3       G Gambhir         1699         2433
# 4        MS Dhoni         2232         1328
# 5       RG Sharma         2344         1863
# 6      RV Uthappa         1516         2262
# 7        S Dhawan         2262         1299
# 8        SK Raina         2647         1893
# 9         V Kohli         2391         2027

# %%
trace1=go.Bar(x=final['batsman'],y=final['1st innings'],name='1st innings',marker={'color':'#00a65a'})
trace2=go.Bar(x=final['batsman'],y=final['2nd innings'],name='2nd innings',marker={'color':'#a6a65a'})

data=[trace1,trace2]
layout=go.Layout(title='inning by scores',xaxis={'title':'batsman'},yaxis={'title':'runs'},barmode='overlay')
fig=go.Figure(data=data,layout=layout)
fig.show()

# %%
trace1=go.Bar(x=final['batsman'],y=final['1st innings'],name='1st innings',marker={'color':'#00a65a'})
trace2=go.Bar(x=final['batsman'],y=final['2nd innings'],name='2nd innings',marker={'color':'#a6a65a'})

data=[trace1,trace2]
layout=go.Layout(title='inning by scores',xaxis={'title':'batsman'},yaxis={'title':'runs'},barmode='stack')
fig=go.Figure(data=data,layout=layout)
fig.show()

# %%
trace1=go.Bar(x=final['batsman'],y=final['1st innings'],name='1st innings',marker={'color':'#00a65a'})
trace2=go.Bar(x=final['batsman'],y=final['2nd innings'],name='2nd innings',marker={'color':'#a6a65a'})

data=[trace1,trace2]
layout=go.Layout(title='inning by scores',xaxis={'title':'batsman'},yaxis={'title':'runs'})
fig=go.Figure(data=data,layout=layout)
fig.show()

# %% [markdown]
# ### Bubble plot

# %%
new_ipl=new_ipl[new_ipl['batsman_runs']==6]
six=new_ipl.groupby('batsman')['batsman_runs'].count()
x=df.merge(six,on='batsman')

trace=go.Scatter(x=x['avg'],y=x['sr'],mode='markers',hovertext=x['batsman'],marker={'size':x['batsman_runs']})
data=[trace]
layout=go.Layout(title='batsman Avg vs sr',xaxis={'title':'Avg'},yaxis={'title':'sr'})
fig=go.Figure(data=data,layout=layout)
fig.show()

# %%
new_ipl=new_ipl[new_ipl['batsman_runs']==6]
six=new_ipl.groupby('batsman')['batsman_runs'].count()
x=df.merge(six,on='batsman')

trace=go.Scatter(x=x['avg'],y=x['sr'],mode='markers',hovertext=x['batsman'],marker={'color':x['avg'],'size':x['batsman_runs']})
data=[trace]
layout=go.Layout(title='batsman Avg vs sr',xaxis={'title':'Avg'},yaxis={'title':'sr'})
fig=go.Figure(data=data,layout=layout)
fig.show()

# %% [markdown]
# ##### Box plot

# %%
match_agg=delivery.groupby(['match_id'])['total_runs'].sum().reset_index()
season_wise=match_agg.merge(matches,left_on='match_id',right_on='id')[['match_id','total_runs','season']]
season_wise
# Out:
#      match_id  total_runs  season
# 0           1         379    2017
# 1           2         371    2017
# 2           3         367    2017
# 3           4         327    2017
# 4           5         299    2017
# ..        ...         ...     ...
# 631       632         277    2016
# 632       633         317    2016
# 633       634         302    2016
# 634       635         325    2016
# 635       636         408    2016
#
# [636 rows x 3 columns]

# %%
trace=go.Box(x=season_wise['total_runs'],name='all seasons',marker={'color':'#00a65a'})
data=[trace]
layout=go.Layout(title='Total Score Analysis',xaxis={'title':'Total Score'})

fig=go.Figure(data=data,layout=layout)

fig.show()

# %%
trace1=go.Box(x=season_wise[season_wise['season']==2017]['total_runs'],name='2017',marker={'color':'#00a65a'})
trace2=go.Box(x=season_wise[season_wise['season']==2008]['total_runs'],name='2008',marker={'color':"#a6001e"})
data=[trace1,trace2]
layout=go.Layout(title='Total Score Analysis',xaxis={'title':'Total Score'})

fig=go.Figure(data=data,layout=layout)

fig.show()

# %%
#plot distplot
import plotly.figure_factory as ff
hist_data=[df['avg']]
group_labels=['Average']
fig=ff.create_dist(hist_data,group_labels)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[87], line 5
#       1 #plot distplot
#       2 import plotly.figure_factory as ff
#       3 hist_data=[df['avg']]
#       4 group_labels=['Average']
# ----> 5 fig=ff.create_dist(hist_data,group_labels)
#       6 fig.show()
#
# AttributeError: module 'plotly.figure_factory' has no attribute 'create_dist'

# %%
print(hasattr(ff, "create_distplot"))
# Out:
# False

# %%
import plotly.express as px
fig = px.histogram(
    df,
    x='avg',
    marginal='rug'
)
fig.show()

# %%
fig = px.histogram(
    df,
    x=['avg','sr'],
    marginal='rug'
)
fig.show()

# %%
fig = px.histogram(
    df,
    x='avg',
    marginal='rug',nbins=10
)
fig.show()

# %% [markdown]
# ### Histogram

# %%
trace=go.Histogram(x=df['sr'],name='strike rate variations')
data=[trace]
layout=go.Layout(title='strike rate analysis',xaxis={'title':'strike rates'})
fig=go.Figure(data=data,layout=layout)
fig.show()

# %%
trace=go.Histogram(x=df['sr'],name='strike rate variations',xbins={'size':10})
data=[trace]
layout=go.Layout(title='strike rate analysis',xaxis={'title':'strike rates'})
fig=go.Figure(data=data,layout=layout)
fig.show()

# %%
trace=go.Histogram(x=df['sr'],name='strike rate variations',xbins={'size':5,'start':100,'end':200})
data=[trace]
layout=go.Layout(title='strike rate analysis',xaxis={'title':'strike rates'})
fig=go.Figure(data=data,layout=layout)
fig.show()

# %% [markdown]
# #### heatmap

# %%
six=delivery[delivery['batsman_runs']==6]
six=six.groupby(['batting_team','over'])['batsman_runs'].count().reset_index()
six
# Out:
#             batting_team  over  batsman_runs
# 0    Chennai Super Kings     1             9
# 1    Chennai Super Kings     2            21
# 2    Chennai Super Kings     3            49
# 3    Chennai Super Kings     4            45
# 4    Chennai Super Kings     5            53
# ..                   ...   ...           ...
# 290  Sunrisers Hyderabad    16            31
# 291  Sunrisers Hyderabad    17            25
# 292  Sunrisers Hyderabad    18            49
# 293  Sunrisers Hyderabad    19            58
# 294  Sunrisers Hyderabad    20            44
#
# [295 rows x 3 columns]

# %%
#plot Heatmap
trace=go.Heatmap(x=six['batting_team'],y=six['over'],z=six['batsman_runs'])
data=[trace]
layout=go.Layout(title='six Heatmap')
fig=go.Figure(data=data,layout=layout)
fig.show()

# %%
#side by side heatmap
dots=delivery[delivery['batsman_runs']==0]
dots=dots.groupby(['batting_team','over'])['batsman_runs'].count().reset_index()

# %%
from plotly.subplots import make_subplots

trace1=go.Heatmap(x=six['batting_team'],y=six['over'],z=six['batsman_runs'].values.tolist())
trace2=go.Heatmap(x=dots['batting_team'],y=dots['over'],z=dots['batsman_runs'].values.tolist())

data=[trace1,trace2]
layout=go.Layout(title='no of six per over')
fig=make_subplots(rows=1,cols=2,subplot_titles=["6's","0's"],shared_yaxes=True)
fig.append_trace(trace1,1,1)
fig.append_trace(trace2,1,2)
fig.show()
