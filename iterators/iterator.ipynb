# %% [markdown]
# Iteration
#
# Iteration is the process of visiting one element at a time from a collection.
# Think of it as moving through data one by one.

# %%
numbers = [10, 20, 30]
for num in numbers:
    print(num)
# Out:
# 10
# 20
# 30

# %% [markdown]
# Iterate
#
# To access elements one after another
#
# Iterator
#
# An iterator is an object that remembers its current position while iterating.
# It gives the next value whenever asked.
#
# Python creates an iterator using
# >iter()
# gets values using
# >next()
#  iterator An object that actually returns values one by one.
#
#  it = iter(numbers)
#  it is an iterator
#
# iterable  is an object which one can iterate over
# it geneartes an iterator when passed to iter()method

# %%
numbers = [10, 20, 30]
#fetch the iterator
it = iter(numbers)
#step2--->next()
print(next(it))
print(next(it))
print(next(it))
# Out:
# 10
# 20
# 30

# %% [markdown]
# if I call next(it)
# give error
# >StopIteration

# %%
print(next(it))
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(next(it))
#
# StopIteration:

# %% [markdown]
# example:-
# Book = Iterable
# Bookmark = Iterator
# Reading one page at a time = Iteration

# %% [markdown]
# Iterable
# An object you can iterate over.
# example:-
# list
# tuple
# string
# set
# dictionary
# range
# file

# %% [markdown]
# How Python for-loop Works

# %%
for x in [1,2,3]:
    print(x)
# Out:
# 1
# 2
# 3

# %% [markdown]
# Python actually does something similar to

# %%
numbers = [1,2,3]
it = iter(numbers)
while True:
    try:
        x = next(it)
        print(x)
    except StopIteration:
        break
# Out:
# 1
# 2
# 3

# %%
l=[1,2,3]
print(type(l))
#l is an iterable
it=iter(l)
print(type(it))
# Out:
# <class 'list'>
# <class 'list_iterator'>

# %% [markdown]
# point to remember
#
# every iterator is also and iterable
# not all iterables are iterators
#
# trick
#
# every iterable has an iter function
# every iterator has both iter function as well as a next function

# %% [markdown]
# purpose of iter()
# Convert an iterable into an iterator.

# %%
nums = [5,6,7]
it = iter(nums)
print(it)

# %% [markdown]
# purpose of next()
# Return the next item.

# %%
it = iter([10,20,30])
print(next(it))
# Out:
# 10

# %% [markdown]
# iterator
# an iterator is an object that allows the programmer to traverse through a sequence of data without having to store the entire data in memory

# %% [markdown]
# why iterator was created
# imagine a file with 50 Gb
# if python load everything
# need lots of memory
#
# instead iterator reads one by one need less memory (negligable)
#
# Lazy Evaluation
# Iterator does not calculate everything immediately.
# It calculates only when needed.

# %%
import sys
l1=[x for x in range(1,10000)]
print(sys.getsizeof(l1))
l2=[x for x in range(1,1000)]
print(sys.getsizeof(l2))
l3=[x for x in range(1,100000)]
print(sys.getsizeof(l3))
l4=[x for x in range(1,10)]
print(sys.getsizeof(l4))
# Out:
# 85176
# 8856
# 800984
# 184

# %%
import sys 
x=range(1,10000)
print(sys.getsizeof(x))
y=range(1,100000)
print(sys.getsizeof(y))
z=range(1,1000000)
print(sys.getsizeof(z))
a=range(1,1000000000)
print(sys.getsizeof(a))
# Out:
# 48
# 48
# 48
# 48

# %% [markdown]
# objects that are iterable
# list
# tuple
# string
# set
# dictionary
# range
# file
# bytes
# bytearray

# %%
for x in "Python":
    print(x)
# Out:
# P
# y
# t
# h
# o
# n

# %%
student = {
    "name":"Ankit",
    "age":20
}
for key in student:
    print(key)
# Out:
# name
# age

# %%
for key, value in student.items():
    print(key, value)
# Out:
# name Ankit
# age 20

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# check iterator

# %%
from collections.abc import Iterator
numbers = [1,2,3]
print(isinstance(numbers, Iterator))
# Out:
# False

# %%
#need
it = iter(numbers)
print(isinstance(it, Iterator))
# Out:
# True

# %% [markdown]
# second method
# use dir
# if we find iter function obj are iterable
# if we find iter and next both function object is an iterator

# %%
l=[1,2,3]
dir(l)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
it=iter(l)
dir(it)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__length_hint__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
nums = [1,2,3]
print(type(nums))
it = iter(nums)
print(type(it))
# Out:
# <class 'list'>
# <class 'list_iterator'>

# %% [markdown]
# the difference between iteration and iterator

# %% [markdown]
# Iteration: The process of visiting elements one by one.
#
# Iterator: The object that performs this process and remembers the current position.

# %% [markdown]
# Iteration	The process of accessing   elements one by one.
#
# Iterate	    The action of moving through elements.
#
# Iterable	An object that can be iterated over (e.g., list, tuple, string).
#
# Iterator	An object created from an iterable that returns the next item with
# next() and keeps track of its current position.
#
# iter()	Creates an iterator from an iterable.
#
# next()	Returns the next value from an iterator.
#
# StopIteration   Exception raised when the iterator has no more values.

# %% [markdown]
# making our own for loop

# %%
def my_loop(iterable):
    iterator=iter(iterable)
    while True:
        try:
            print(next(iterator))
        except StopIteration:
            break

l=range(1,10)
print(my_loop(l))
print(type(my_loop))
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# None
# <class 'function'>

# %%
num=[1,2,3]
it=iter(num)
print(id(it))
print(type(it))
iter1=iter(it)
print(id(iter1))
print(type(iter1))
# Out:
# 2373492445712
# <class 'list_iterator'>
# 2373492445712
# <class 'list_iterator'>

# %%
class my_range_iterator:
    def __init__(self,iterable_obj):
        self.iterable=iterable_obj

    def __iter__(self):
        return self
    
    def __next__(self):
        if self.iterable.start>=self.iterable.end:
            raise StopIteration
        current=self.iterable.start
        self.iterable.start+=1
        return current

# %%
class my_range:
    def __init__(self,start,end):
        self.start=start
        self.end=end
        
    def __iter__(self):
        return my_range_iterator(self)

# %% [markdown]
# __iter__() return self here
# Because the object itself is already the iterator. It keeps track of its current position (self.current), so there's no need to create another object.

# %%
for i in my_range(1,10):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
x=my_range(1,20)
print(x)
print(type(x))
print(iter(x))
# Out:
# ...
# <class '__main__.my_range'>
# ...
